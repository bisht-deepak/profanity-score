# %% [markdown]
# <a href="https://www.kaggle.com/code/thethirdchapter/profanity-score?scriptVersionId=119135140" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
#importing required libraries
import pandas as pd
import re

# %%
#reading datasets
#dataset containing 
df= pd.read_csv(r"/kaggle/input/democratvsrepublicantweets/ExtractedTweets.csv")
df.head()
# Out:
#       Party         Handle                                              Tweet
# 0  Democrat  RepDarrenSoto  Today, Senate Dems vote to #SaveTheInternet. P...
# 1  Democrat  RepDarrenSoto  RT @WinterHavenSun: Winter Haven resident / Al...
# 2  Democrat  RepDarrenSoto  RT @NBCLatino: .@RepDarrenSoto noted that Hurr...
# 3  Democrat  RepDarrenSoto  RT @NALCABPolicy: Meeting with @RepDarrenSoto ...
# 4  Democrat  RepDarrenSoto  RT @Vegalteno: Hurricane season starts on June...

# %%
#creating a set of profane terms using dataset available in kaggle
df_profane= pd.read_csv(r"/kaggle/input/bad-bad-words/bad-words.csv")
set_profane= set(df_profane["jigaboo"])

# %%
def calculate_profanity_score(tweet):
    
    try:
        tweet = tweet.lower()  # converts tweet to lowercase
        tweet = re.sub(r"[^\w\s]", "", tweet) #removes punctuation marks
        total_profanity_words = sum(tweet.count(word) for word in set_profane)  # count occurrences of each profanity in the tweet
        profanity_score = total_profanity_words / len(tweet.split())  # calculate the profanity score as a ratio of profanity words to total words in the tweet
    except ZeroDivisionError:
        profanity_score= 0
        
    return profanity_score

# %%
#storing the profanity score of each tweet in a new column
df["Profanity Score"]= df.apply(lambda row: calculate_profanity_score(row["Tweet"]), axis= 1)

# %%
df.head()
# Out:
#       Party         Handle                                              Tweet  \
# 0  Democrat  RepDarrenSoto  Today, Senate Dems vote to #SaveTheInternet. P...
# 1  Democrat  RepDarrenSoto  RT @WinterHavenSun: Winter Haven resident / Al...
# 2  Democrat  RepDarrenSoto  RT @NBCLatino: .@RepDarrenSoto noted that Hurr...
# 3  Democrat  RepDarrenSoto  RT @NALCABPolicy: Meeting with @RepDarrenSoto ...
# 4  Democrat  RepDarrenSoto  RT @Vegalteno: Hurricane season starts on June...
#
#    Profanity Score
# 0         0.058824
# 1         0.000000
# 2         0.157895
# 3         0.055556
# 4         0.000000
